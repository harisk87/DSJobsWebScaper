# %% [markdown]
# # HARI SIVAKUMAR

# %% [markdown]
# # This is my first web scraper. It is an extension of ideas introduced in Lecture 2 of Harvard's CS109 course from Fall 2015, and also of a project by [Jesse Steinweg-Woods](https://jessesw.com/Data-Science-Skills/)

# %% [markdown]
# # The goal of this project is to find out
# ## 1) How many data science jobs are currently available
# ## 2) Where most jobs are
# ## 3) Who are the big employers
#
# ### Disclaimer: Some of the code is adapted from  Lecture 2 of Harvard's CS109 course from Fall 2015

# %%
## all imports
from IPython.display import HTML
import numpy as np
import urllib2
import bs4 
import time
import operator
import socket
import cPickle
import re # regular expressions

from pandas import Series
import pandas as pd
from pandas import DataFrame

import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## First, I create a BeautifulSoup object by scraping the first page obtained when searching indeed.com for "Data Scientist"

# %%
# Fixed url for job postings containing data scientist
url = 'http://www.indeed.com/jobs?q=data+scientist&l='
# read the website
source = urllib2.urlopen(url).read()
# parse html code
bs_tree = bs4.BeautifulSoup(source, 'html.parser')

# %% [markdown]
# ## On that page, I find the piece of the HTML code that lists the total number of job results

# %%
job_count_string = bs_tree.find(id = 'searchCount').contents[0]
#print job_count_string
#Jobs 1 to 50 of 21,383

#print job_count_string.split()
#[u'Jobs', u'1', u'to', u'50', u'of', u'21,383']

#print job_count_string.split()[-1]
#21,383

#print type(job_count_string.split())
#<type 'list'>

jc = job_count_string.split()[-1]
jc = jc.replace(",", "")
print 'There are ' + jc + ' Data Scientist job openings'
jc = int(jc)
# Out:
# There are 21444 Data Scientist job openings

# %% [markdown]
# ## It would seem that there are over 21,000 Data Scientist job openings!!
#
# ## Since there are only 10 results per page, I scrape all the pages (page by page) to extract all the locations, company names, and links to the job postings.

# %%
# The website is only listing 10 results per page, 
# so we need to scrape them page after page
num_pages = int(np.ceil(jc/10.0))

# Lambda expressions return the value of the expression inside it.
# In this case, it will return a string with new line characters replaced by spaces.
rem_nl = lambda s: s.replace("\n", " ")

base_url = 'http://www.indeed.com'
job_links = []
location = [];
company_name = [];
job_title = [];
for i in range(num_pages): #do range(num_pages) if you want them all
    print 'Scraped page ' + str(i+1)
    url = base_url + '/jobs?q=data+scientist&start=' + str(i*10)
    html_page = urllib2.urlopen(url).read() 
    bs_tree = bs4.BeautifulSoup(html_page)
    
    # id = resultsCol is the attribute where the search results are
    job_link_area = bs_tree.find(id = 'resultsCol')
    
    # extracting all the job postings and putting them into the list when they are of class row result.
    # The reason it is done this way is because some of them are of class "row result" and others of class
    # " row result" with a whitespace, making it weird for beautiful soup. 
    job_postings = job_link_area.findAll("div")
    job_postings = [jp for jp in job_postings if not jp.get('class') is None 
                     and ''.join(jp.get('class')) =="rowresult"]
    
    # extract the job ids in the posting which have attribute data-jk
    job_ids = [jp.get('data-jk') for jp in job_postings];

    # extracting location which has heading span and attribute location. Need to check if any of them have weird
    # whitespaces, in which case the above method might be better
    # get text gives us the text inside <span class = location
    locations_this_page = [str(jp.find("span","location").get_text()) for jp in job_postings];
    
    # Same thing for company names, except get_text gives us something with \n new lines and white spaces. 
    # So we use the rem_nl method to remove the new lines and the strip() to remove white spaces
    company_names_this_page = [str(rem_nl(jp.find("span",{"company","a"}).get_text())).strip() for jp in job_postings]    
    
    # go after each link
    for id in job_ids:
        job_links.append(base_url + '/rc/clk?jk=' + id)
    # Append all the job locations from this page
    for loc in locations_this_page:
        location.append(loc)
    # Append all the company names from this page
    for cn in company_names_this_page:
        company_name.append(cn)

# %% [markdown]
# ## The job locations are not always available in a consistent format. Sometimes, jobs are remote and other times, location is listed as "United States". Sometimes, the state is given but not the city. At first, I tried to account for all cases but it got a bit tiresome, so I decided to just remove data points for which the city and state were both not available

# %%
# Was planning to account for all cases, but there are too many

# for i in xrange(len(location)):
#     if location[i] == 'Remote':
#         location[i] = 'Remote, NS'
#     elif location[i] == 'United States':
#         location[i] = 'USA, NS'

# So if the format is not city, state, I'm throwing away the data

tmp = [loc.split(',') for loc in location]
del_idx = [];

# First, I get all the indices where the locations are not of format A , B 

for i in range(len(tmp)):
    x = tmp[i]
    if len(x) == 1:
        del_idx.append(i)

# An alternative way to do it based on try except

# for i in range(len(tmp)):
#     x = tmp[i]
#     try:
#         x[1]
#     except:
#         del_idx.append(i)


# Now delete all elements that are in del_idx from job_links, location and company name

del_set = set(del_idx)
job_links = [v for i, v in enumerate(job_links) if i not in del_set]
location = [v for i, v in enumerate(location) if i not in del_set]
company_name = [v for i, v in enumerate(company_name) if i not in del_set]



# for each location, split it by the comma. Then the first (0th) element is the city name
city = [loc.split(',')[0] for loc in location]

# The second (1th) element is the state. This could have garbage, so we just get the first 2 letters which is the
# state code
state = [loc.split(',')[1].strip()[0:2] for loc in location]

# %% [markdown]
# ## Having scraped all this data, I first use cPickle to store it so I don't lose it!

# %%
with open('data/hari_scraped_job_links', 'wb') as f:
    cPickle.dump(job_links, f)
with open('data/hari_scraped_locations', 'wb') as f:
    cPickle.dump(location, f)
with open('data/hari_company_names', 'wb') as f:
    cPickle.dump(company_name, f)

# %% [markdown]
# ## So let's take a look at all the jobs we scraped!

# %%
scraped_dict = {"Company Name": company_name, "City": city, "State": state, "Link": job_links}
df = pd.DataFrame(scraped_dict)
df
# Out:
#                       City                Company Name  \
# 0                Las Vegas            Zappos.com, Inc.
# 1                San Diego                   CoreLogic
# 2            Santa Barbara               Impact Radius
# 3                Greenbelt         ADNET Systems, Inc.
# 4                Sunnyvale                     Jetlore
# 5                 New York           SecurityScorecard
# 6                 Bellevue              Neal Analytics
# 7                  Atlanta                    SunTrust
# 8                 Bellevue                   Concordis
# 9                 Columbus              JPMorgan Chase
# 10           San Francisco                    Mines.io
# 11             Santa Clara                     Picarro
# 12                  Austin             Main Street Hub
# 13     Fort George G Meade    National Security Agency
# 14             Minneapolis          Polaris Industries
# 15                New York                 PerformLine
# 16                  Boston                      Drizly
# 17            Redwood City                  Shutterfly
# 18              Washington                  Quantifind
# 19                Bellevue                        EBay
# 20               Palo Alto                Tesla Motors
# 21                  Draper        Owlet Baby Care Inc.
# 22                  Sumter         Booz Allen Hamilton
# 23               Las Vegas            Zappos.com, Inc.
# 24               Cambridge                      Biogen
# 25               Palo Alto                SurveyMonkey
# 26      Santa Clara Valley                       Apple
# 27                New York              JPMorgan Chase
# 28           San Francisco                   Pinterest
# 25     http://www.indeed.com/rc/clk?jk=b79b232d359d37c6    CA
# 26     http://www.indeed.com/rc/clk?jk=389ee2e7c36467d2    CA
# 27     http://www.indeed.com/rc/clk?jk=6ae739043f133380    NY
# 28     http://www.indeed.com/rc/clk?jk=e31d2deea5c0fac6    CA
# 29     http://www.indeed.com/rc/clk?jk=c5d65a515d741430    VA
# ...                                                 ...   ...
# 19337  http://www.indeed.com/rc/clk?jk=94660fa87557c6eb    TX
# 19338  http://www.indeed.com/rc/clk?jk=cca36b3d4125fb8a    UT
# 19339  http://www.indeed.com/rc/clk?jk=7efb7e6833b325c8    TX
# 19340  http://www.indeed.com/rc/clk?jk=31dd6271b4359170    IL
# 19341  http://www.indeed.com/rc/clk?jk=2b9e2b59387ab420    MI
# 19342  http://www.indeed.com/rc/clk?jk=17db635e34809ac3    CA
# 19343  http://www.indeed.com/rc/clk?jk=9b02913ecb8c8306    NY
# 19344  http://www.indeed.com/rc/clk?jk=8d11e7ad1eed279a    MN
# 19345  http://www.indeed.com/rc/clk?jk=812b057d1e1bdbf4    NY
# 19346  http://www.indeed.com/rc/clk?jk=2ee64d0a2ad3620c    OH
# 19347  http://www.indeed.com/rc/clk?jk=a2577dea5dab2b83    CA
# 19348  http://www.indeed.com/rc/clk?jk=f9a3ee7ab71ffb1b    GA
# 19349  http://www.indeed.com/rc/clk?jk=31dd6271b4359170    IL
# 19350  http://www.indeed.com/rc/clk?jk=2b9e2b59387ab420    MI
# 19351  http://www.indeed.com/rc/clk?jk=17db635e34809ac3    CA
# 19352  http://www.indeed.com/rc/clk?jk=9b02913ecb8c8306    NY
# 19353  http://www.indeed.com/rc/clk?jk=8d11e7ad1eed279a    MN
# 19354  http://www.indeed.com/rc/clk?jk=812b057d1e1bdbf4    NY
# 19355  http://www.indeed.com/rc/clk?jk=2ee64d0a2ad3620c    OH
# 19356  http://www.indeed.com/rc/clk?jk=a2577dea5dab2b83    CA
# 19357  http://www.indeed.com/rc/clk?jk=f9a3ee7ab71ffb1b    GA
# 19358  http://www.indeed.com/rc/clk?jk=31dd6271b4359170    IL
# 19359  http://www.indeed.com/rc/clk?jk=2b9e2b59387ab420    MI
# 19360  http://www.indeed.com/rc/clk?jk=17db635e34809ac3    CA
# 19361  http://www.indeed.com/rc/clk?jk=9b02913ecb8c8306    NY
# 19362  http://www.indeed.com/rc/clk?jk=8d11e7ad1eed279a    MN
# 19363  http://www.indeed.com/rc/clk?jk=812b057d1e1bdbf4    NY
# 19364  http://www.indeed.com/rc/clk?jk=2ee64d0a2ad3620c    OH
# 19365  http://www.indeed.com/rc/clk?jk=a2577dea5dab2b83    CA
# 19366  http://www.indeed.com/rc/clk?jk=f9a3ee7ab71ffb1b    GA
#
# [19367 rows x 4 columns]

# %% [markdown]
# ## There still seem to be over 19,000 jobs after removing the data without location in the correct format

# %%
df.describe()
# Out:
#            City Company Name  \
# count     19367        19367
# unique      279          658
# top     Stanton     Syngenta
# freq       2045         2045
#
#                                                     Link  State
# count                                              19367  19367
# unique                                               789     46
# top     http://www.indeed.com/rc/clk?jk=8d11e7ad1eed279a     CA
# freq                                                2045   3179

# %% [markdown]
# ## It is somewhat odd that this company Syngenta is hiring 2045 data scientists! It is possible that this company is based in this city called Stanton, since they both have 2045 results.  A single company with 2045 data scientist positions?? Let's investigate!

# %%
df[df.City == 'Stanton'].head(20)
# Out:
#          City Company Name                                              Link  \
# 963   Stanton     Syngenta  http://www.indeed.com/rc/clk?jk=8d11e7ad1eed279a
# 972   Stanton     Syngenta  http://www.indeed.com/rc/clk?jk=8d11e7ad1eed279a
# 983   Stanton     Syngenta  http://www.indeed.com/rc/clk?jk=8d11e7ad1eed279a
# 990   Stanton     Syngenta  http://www.indeed.com/rc/clk?jk=8d11e7ad1eed279a
# 1001  Stanton     Syngenta  http://www.indeed.com/rc/clk?jk=8d11e7ad1eed279a
# 1008  Stanton     Syngenta  http://www.indeed.com/rc/clk?jk=8d11e7ad1eed279a
# 1016  Stanton     Syngenta  http://www.indeed.com/rc/clk?jk=8d11e7ad1eed279a
# 1028  Stanton     Syngenta  http://www.indeed.com/rc/clk?jk=8d11e7ad1eed279a
# 1037  Stanton     Syngenta  http://www.indeed.com/rc/clk?jk=8d11e7ad1eed279a
# 1044  Stanton     Syngenta  http://www.indeed.com/rc/clk?jk=8d11e7ad1eed279a
# 1053  Stanton     Syngenta  http://www.indeed.com/rc/clk?jk=8d11e7ad1eed279a
# 1062  Stanton     Syngenta  http://www.indeed.com/rc/clk?jk=8d11e7ad1eed279a
# 1073  Stanton     Syngenta  http://www.indeed.com/rc/clk?jk=8d11e7ad1eed279a
# 1082  Stanton     Syngenta  http://www.indeed.com/rc/clk?jk=8d11e7ad1eed279a
# 1089  Stanton     Syngenta  http://www.indeed.com/rc/clk?jk=8d11e7ad1eed279a
# 1100  Stanton     Syngenta  http://www.indeed.com/rc/clk?jk=8d11e7ad1eed279a
# 1107  Stanton     Syngenta  http://www.indeed.com/rc/clk?jk=8d11e7ad1eed279a
# 1115  Stanton     Syngenta  http://www.indeed.com/rc/clk?jk=8d11e7ad1eed279a
# 1125  Stanton     Syngenta  http://www.indeed.com/rc/clk?jk=8d11e7ad1eed279a
# 1134  Stanton     Syngenta  http://www.indeed.com/rc/clk?jk=8d11e7ad1eed279a
#
#      State
# 963     MN
# 972     MN
# 983     MN
# 990     MN
# 1001    MN
# 1008    MN
# 1016    MN
# 1028    MN
# 1037    MN
# 1044    MN
# 1053    MN
# 1062    MN
# 1073    MN
# 1082    MN
# 1089    MN
# 1100    MN
# 1107    MN
# 1115    MN
# 1125    MN
# 1134    MN

# %% [markdown]
# ## Ah-hah, mystery solved! We see that the job link in each of these 2045 job postings is exactly the same. So really, it is 2045 ads for the same (single) job with Syngenta. This probably means that there are plenty of duplicates in our data

# %%
df2 = df.drop_duplicates()
df2
# Out:
#                      City                Company Name  \
# 0               Las Vegas            Zappos.com, Inc.
# 1               San Diego                   CoreLogic
# 2           Santa Barbara               Impact Radius
# 3               Greenbelt         ADNET Systems, Inc.
# 4               Sunnyvale                     Jetlore
# 5                New York           SecurityScorecard
# 6                Bellevue              Neal Analytics
# 7                 Atlanta                    SunTrust
# 8                Bellevue                   Concordis
# 9                Columbus              JPMorgan Chase
# 10          San Francisco                    Mines.io
# 11            Santa Clara                     Picarro
# 12                 Austin             Main Street Hub
# 13    Fort George G Meade    National Security Agency
# 14            Minneapolis          Polaris Industries
# 15               New York                 PerformLine
# 16                 Boston                      Drizly
# 17           Redwood City                  Shutterfly
# 18             Washington                  Quantifind
# 19               Bellevue                        EBay
# 20              Palo Alto                Tesla Motors
# 21                 Draper        Owlet Baby Care Inc.
# 22                 Sumter         Booz Allen Hamilton
# 23              Las Vegas            Zappos.com, Inc.
# 24              Cambridge                      Biogen
# 25              Palo Alto                SurveyMonkey
# 26     Santa Clara Valley                       Apple
# 27               New York              JPMorgan Chase
# 28          San Francisco                   Pinterest
# 29                 Reston  Consumer Intelligence Firm
# ...                   ...                         ...
# 940         San Francisco                    Symantec
# 941            Alpharetta               Smartlink LLC
# 942           Sioux Falls              Omnitech, Inc.
# 943         Mountain View          Boomerang Commerce
# 944                Woburn                     Corning
# 945            Pleasanton        Dawar Consulting Inc
# 946            Schaumburg        Zurich North America
# 951              San Jose  Becton Dickinson & Company
# 952       Pinellas County      PeopleFirst Florida HR
# 953                SeaTac                  Ateeca Inc
# 954             St. Louis    Ferguson Consulting, Inc
# 955              Dearborn          Altair Engineering
# 956            Charleston                Sentar, Inc.
# 958           Morrisville                     PHASTAR
# 959               Chicago       University of Chicago
# 960               Milford                Cresttek LLC
# 961         San Francisco                   GSN Games
# 962                Albany        Analytical Chemistry
# 963               Stanton                    Syngenta
# 964              New York                High 5 Games
# 965      Mayfield Village                 Progressive
# 966           Aliso Viejo              Ambry Genetics
# 967            Alpharetta         The Rainmaker Group
# 968            Minnetonka          Vital Images, INC.
# 969               Houston                      Panton
# 970         Overland Park     Quintiles Transnational
# 981                Rahway                       Merck
# 985    Santa Clara Valley                       Apple
# 953   http://www.indeed.com/rc/clk?jk=bed1b3fa7463d4de    WA
# 954   http://www.indeed.com/rc/clk?jk=0f016965cca8f917    MO
# 955   http://www.indeed.com/rc/clk?jk=c25209c932124b34    MI
# 956   http://www.indeed.com/rc/clk?jk=7c099c557e36784e    SC
# 958   http://www.indeed.com/rc/clk?jk=022da113034486f6    NC
# 959   http://www.indeed.com/rc/clk?jk=31dd6271b4359170    IL
# 960   http://www.indeed.com/rc/clk?jk=2b9e2b59387ab420    MI
# 961   http://www.indeed.com/rc/clk?jk=17db635e34809ac3    CA
# 962   http://www.indeed.com/rc/clk?jk=9b02913ecb8c8306    NY
# 963   http://www.indeed.com/rc/clk?jk=8d11e7ad1eed279a    MN
# 964   http://www.indeed.com/rc/clk?jk=812b057d1e1bdbf4    NY
# 965   http://www.indeed.com/rc/clk?jk=2ee64d0a2ad3620c    OH
# 966   http://www.indeed.com/rc/clk?jk=a2577dea5dab2b83    CA
# 967   http://www.indeed.com/rc/clk?jk=f9a3ee7ab71ffb1b    GA
# 968   http://www.indeed.com/rc/clk?jk=a8b1fff81fa83cad    MN
# 969   http://www.indeed.com/rc/clk?jk=e30924cbf01dd8aa    TX
# 970   http://www.indeed.com/rc/clk?jk=449c6d6e8a14acdb    KS
# 981   http://www.indeed.com/rc/clk?jk=2423a6a18c757e70    NJ
# 985   http://www.indeed.com/rc/clk?jk=290e8e6f4e512561    CA
# 987   http://www.indeed.com/rc/clk?jk=cca36b3d4125fb8a    UT
# 1024  http://www.indeed.com/rc/clk?jk=abd6fe919f1e27eb    CA
#
# [789 rows x 4 columns]

# %% [markdown]
# ## Having dropped all the duplicates, it turns out that there are really only 789 job postings for data scientist :(
#
# ### This could also have been seen if we had observed the number of unique job ids in df.describe()

# %%
df2.describe()
# Out:
#             City Company Name  \
# count        789          789
# unique       279          658
# top     New York        Apple
# freq          49            9
#
#                                                     Link State
# count                                                789   789
# unique                                               789    46
# top     http://www.indeed.com/rc/clk?jk=0c4a42ae2bde0647    CA
# freq                                                   1   189

# %% [markdown]
# ## NYC has at least 49 job openings, while Apple has 9 open data scientist positions. We can verify that each of these jobs is a unique opening

# %%
df2[df2['Company Name'] == 'Apple']
# Out:
#                     City Company Name  \
# 26    Santa Clara Valley        Apple
# 229   Santa Clara Valley        Apple
# 282   Santa Clara Valley        Apple
# 653        San Francisco        Apple
# 702   Santa Clara Valley        Apple
# 768   Santa Clara Valley        Apple
# 882   Santa Clara Valley        Apple
# 985   Santa Clara Valley        Apple
# 1024  Santa Clara Valley        Apple
#
#                                                   Link State
# 26    http://www.indeed.com/rc/clk?jk=389ee2e7c36467d2    CA
# 229   http://www.indeed.com/rc/clk?jk=162f17321fba22aa    CA
# 282   http://www.indeed.com/rc/clk?jk=86489240a6f6aa6c    CA
# 653   http://www.indeed.com/rc/clk?jk=584c5fbba3fbf8ae    CA
# 702   http://www.indeed.com/rc/clk?jk=2f75bcad6b7ec1ef    CA
# 768   http://www.indeed.com/rc/clk?jk=63314403426d0899    CA
# 882   http://www.indeed.com/rc/clk?jk=41fbd1fbc89d2a69    CA
# 985   http://www.indeed.com/rc/clk?jk=290e8e6f4e512561    CA
# 1024  http://www.indeed.com/rc/clk?jk=abd6fe919f1e27eb    CA

# %% [markdown]
# ## Let's see the distribution jobs by state, for the top 20 states

# %%
grouped_by_state = df2.groupby('State')['Company Name']
# df.groupby('A') is just syntactic sugar for df.groupby(df['A'])
num_jobs_per_state = grouped_by_state.count().sort_values(ascending=False)
num_jobs_per_state[0:20].plot(kind='bar')
plt.xlabel('State')
plt.ylabel('Number of jobs')

# %% [markdown]
# ## And also the top hirers

# %%
grouped_by_cn = df2.groupby('Company Name')['Link']
# df.groupby('A') is just syntactic sugar for df.groupby(df['A'])
num_jobs_per_cn = grouped_by_cn.count().sort_values(ascending=False)
num_jobs_per_cn[:15].plot(kind='bar')
plt.xlabel('Company')
plt.ylabel('Number of jobs')

# %% [markdown]
# ## Some data for my own perusal

# %%
df2[df2['State'] == 'NC']
# Out:
#             City                     Company Name  \
# 71   Morrisville                         MaxPoint
# 184      Raleigh                     Capital Bank
# 230    Charlotte                             TIAA
# 281    Charlotte                        U.S. Bank
# 377  Mooresville                           Lowe's
# 443    Charlotte                              UTC
# 539  Morrisville                    Direct Client
# 565      Raleigh  North Carolina State University
# 958  Morrisville                          PHASTAR
#
#                                                  Link State
# 71   http://www.indeed.com/rc/clk?jk=401165ae15083eea    NC
# 184  http://www.indeed.com/rc/clk?jk=a9a1683f2fd77e02    NC
# 230  http://www.indeed.com/rc/clk?jk=52798a59c9b1397d    NC
# 281  http://www.indeed.com/rc/clk?jk=cafaa123d236642d    NC
# 377  http://www.indeed.com/rc/clk?jk=af640828b929a15a    NC
# 443  http://www.indeed.com/rc/clk?jk=8fbb850183563c9e    NC
# 539  http://www.indeed.com/rc/clk?jk=be217a513d5f7b62    NC
# 565  http://www.indeed.com/rc/clk?jk=54723054849ae705    NC
# 958  http://www.indeed.com/rc/clk?jk=022da113034486f6    NC

# %%
df2[df2['Company Name'] == 'IBM']
# Out:
#            City Company Name  \
# 81   Washington          IBM
# 641  Washington          IBM
# 645   Cleveland          IBM
# 703      Austin          IBM
#
#                                                  Link State
# 81   http://www.indeed.com/rc/clk?jk=9f28346a5152e4fe    DC
# 641  http://www.indeed.com/rc/clk?jk=edf4480b47755e05    DC
# 645  http://www.indeed.com/rc/clk?jk=927410f8de15b6e6    OH
# 703  http://www.indeed.com/rc/clk?jk=7efb7e6833b325c8    TX

# %% [markdown]
# # Future work

# %% [markdown]
# ## There are some interesting future steps we can take
# ### 1) We can obtain data of zip codes associated with each city, and plot a heatmap of jobs within the US, possibly using Kernel Density Estimation
# ### 2) We can classify the locations by broader headings (e.g. Santa Clara, Sunnyvale etc ==> South Bay, Los Angeles, Irvine, etc ==> Greater LA, Seattle, Bellevue, Redmond ==> Greater Seattle). This would give a more accurate distribution of where the jobs are
# ### 3) We can then scrape the job links for different skills that employers are looking for. Based on the classifications from (2), we can see if there is a pattern between the location of job and the skills required.
# #### skills e.g. : skill_set = {'mapreduce': 0, 'spark': 0, 'hadoop': 0, 'R': 0, 'python': 0}
